# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # data
#
# * pelvic_incidence : 골반 입사
# * pelvic_tilt : 골반 기울기
# * lumbar_lordosis_angle : 요추 전만 각도
# * sacral_slope : 천골 경사
# * pelvic_radius : 골반 반경
# * degree_spondylolisthesis : 척추전방전위증
# * pelvic_slope : 골반 경사
# * Direct_tilt : 다이렉트 틸트
# * thoracic_slope : 흉부 경사
# * cervical_tilt : 경추 기울기
# * sacrum_angle : 천골 각도
# * scoliosis_slope : 척추 측만증
# * class : 정상 또는 비정상

# %%
data_set = pd.read_csv('Dataset_spine.csv')

# %%
data_set.shape
# Out:
# (310, 14)

# %%
data_set.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027817  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
#
#                                          Unnamed: 13
# 0                                                NaN
# ...

# %%
cols = ['pelvic_incidence', 'pelvic_tilt','lumbar_lordosis_angle','sacral_slope','pelvic_radius'
       ,'degree_spondylolisthesis','pelvic_slope','Direct_tilt','thoracic_slope','cervical_tilt'
       ,'sacrum_angle','scoliosis_slope','class']

# %%
data_set.drop('Unnamed: 13', axis=1, inplace=True)

# %%
data_set.columns = cols
data_set.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'Direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope', 'class'],
#       dtype='object')

# %%
data_set.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class
# ...

# %%
data_set.isnull().sum()
# Out:
# pelvic_incidence            0
# pelvic_tilt                 0
# lumbar_lordosis_angle       0
# sacral_slope                0
# pelvic_radius               0
# degree_spondylolisthesis    0
# pelvic_slope                0
# Direct_tilt                 0
# thoracic_slope              0
# cervical_tilt               0
# sacrum_angle                0
# scoliosis_slope             0
# class                       0
# dtype: int64

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   pelvic_slope              310 non-null    float64
#  7   Direct_tilt               310 non-null    float64
#  8   thoracic_slope            310 non-null    float64
#  9   cervical_tilt             310 non-null    float64
#  10  sacrum_angle              310 non-null    float64
#  11  scoliosis_slope           310 non-null    float64
#  12  class                     310 non-null    object
# dtypes: float64(12), object(1)
# ...

# %%
data_set.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# count     310.000000                310.000000    310.000000   310.000000
# mean      117.920655                 26.296694      0.472979    21.321526
# std        13.317377                 37.559027      0.285787     8.639423
# ...

# %%
sns.countplot(data=data_set, x='class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
data_set['class'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: class, dtype: int64

# %%
data_set['class'] = data_set['class'].replace('Abnormal', 1)

# %%
data_set['class'] = data_set['class'].replace('Normal', 0)

# %%
data_set['class'].value_counts()
# Out:
# 1    210
# 0    100
# Name: class, dtype: int64

# %%
data_set_corr = data_set.corr()
data_set_corr_sorted = data_set_corr['class'].sort_values(ascending=False)
data_set_corr_sorted
# Out:
# class                       1.000000
# degree_spondylolisthesis    0.443687
# pelvic_incidence            0.353336
# pelvic_tilt                 0.326063
# lumbar_lordosis_angle       0.312484
# sacral_slope                0.210602
# cervical_tilt               0.100044
# pelvic_slope                0.055865
# sacrum_angle                0.026887
# Direct_tilt                -0.039591
# thoracic_slope             -0.049354
# scoliosis_slope            -0.069315
# pelvic_radius              -0.309857
# Name: class, dtype: float64

# %%
plt.figure(figsize=(12,8))
plt.title('correlation with class')
sns.heatmap(data_set_corr, linewidths=0.5, linecolor='white', cmap='RdPu')
plt.show()

# %%
degree_spondylolisthesis_mean = data_set.describe()['degree_spondylolisthesis']['mean']
degree_spondylolisthesis_mean
# Out:
# 26.29669443786773

# %%
data_set.groupby('class').mean()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# class
# 0             51.685244    12.821414              43.542605      38.86383
# 1             64.692562    19.791111              55.925370      44.90145
#
#        pelvic_radius  degree_spondylolisthesis  pelvic_slope  Direct_tilt  \
# class
# 0         123.890834                  2.186572      0.449880    21.816394
# 1         115.077713                 37.777705      0.483979    21.085875
#
#        thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope
# class
# 0           13.307268      11.514534    -14.528712        26.694019
# 1           12.948913      12.132737    -13.826677        25.146915

# %%
fig, ax = plt.subplots(3, 4, figsize=(15,20))
ax = ax.flatten()

for i in range(len(data_set.columns)-1) :
    sns.boxplot(data=data_set, x='class', y=data_set.iloc[:,i], orient='v', ax=ax[i], palette='magma_r')

# %%
data_class_1 = data_set[data_set['class'] == 1]
data_class_0 = data_set[data_set['class'] == 0]

# %%
col = data_set.describe().columns.tolist()
col.remove('class')
col
# Out:
# ['pelvic_incidence',
#  'pelvic_tilt',
#  'lumbar_lordosis_angle',
#  'sacral_slope',
#  'pelvic_radius',
#  'degree_spondylolisthesis',
#  'pelvic_slope',
#  'Direct_tilt',
#  'thoracic_slope',
#  'cervical_tilt',
#  'sacrum_angle',
#  'scoliosis_slope']

# %%
class_1_mean_datas = []

for i in col :
    mean_data = data_class_1.describe()[i]['mean']
    class_1_mean_datas.append(mean_data)

# %%
class_1_mean_datas = pd.DataFrame(class_1_mean_datas)
class_1_mean_datas.index = col
class_1_mean_datas
# Out:
#                                    0
# pelvic_incidence           64.692562
# pelvic_tilt                19.791111
# lumbar_lordosis_angle      55.925370
# sacral_slope               44.901450
# pelvic_radius             115.077713
# degree_spondylolisthesis   37.777705
# pelvic_slope                0.483979
# Direct_tilt                21.085875
# thoracic_slope             12.948913
# cervical_tilt              12.132737
# sacrum_angle              -13.826677
# scoliosis_slope            25.146915

# %%
class_0_mean_datas = []

for i in col :
    mean_data = data_class_0.describe()[i]['mean']
    class_0_mean_datas.append(mean_data)

# %%
class_0_mean_datas = pd.DataFrame(class_0_mean_datas)
class_0_mean_datas.index = col
class_0_mean_datas
# Out:
#                                    0
# pelvic_incidence           51.685244
# pelvic_tilt                12.821414
# lumbar_lordosis_angle      43.542605
# sacral_slope               38.863830
# pelvic_radius             123.890834
# degree_spondylolisthesis    2.186572
# pelvic_slope                0.449880
# Direct_tilt                21.816394
# thoracic_slope             13.307268
# cervical_tilt              11.514534
# sacrum_angle              -14.528711
# scoliosis_slope            26.694019

# %%
mean_data = pd.concat([class_1_mean_datas, class_0_mean_datas], axis=1)
mean_data.columns = ['class_1', 'class_0']
mean_data
# Out:
#                              class_1     class_0
# pelvic_incidence           64.692562   51.685244
# pelvic_tilt                19.791111   12.821414
# lumbar_lordosis_angle      55.925370   43.542605
# sacral_slope               44.901450   38.863830
# pelvic_radius             115.077713  123.890834
# degree_spondylolisthesis   37.777705    2.186572
# pelvic_slope                0.483979    0.449880
# Direct_tilt                21.085875   21.816394
# thoracic_slope             12.948913   13.307268
# cervical_tilt              12.132737   11.514534
# sacrum_angle              -13.826677  -14.528711
# scoliosis_slope            25.146915   26.694019

# %%
mean_data_difference = abs(abs(mean_data['class_1']) - abs(mean_data['class_0']))
mean_data_difference.sort_values(ascending=False)
# Out:
# degree_spondylolisthesis    35.591133
# pelvic_incidence            13.007317
# lumbar_lordosis_angle       12.382765
# pelvic_radius                8.813122
# pelvic_tilt                  6.969697
# sacral_slope                 6.037620
# scoliosis_slope              1.547104
# Direct_tilt                  0.730519
# sacrum_angle                 0.702035
# cervical_tilt                0.618203
# thoracic_slope               0.358355
# pelvic_slope                 0.034099
# dtype: float64

# %%
data_set.hist(bins=50,figsize=(20,15))
plt.show()

# %%
minimum = 0
maximum = 0

def detect_outlier(feature) :
    first_q = np.percentile(feature, 25)
    third_q = np.percentile(feature, 75)
    IQR = third_q - first_q
    IQR *= 1.5
    minimum = first_q - IQR
    maximum = third_q - IQR
    flag = False
    
    if(minimum > np.min(feature)):
        flag = True
    if(maximum < np.max(feature)):
        flag = True
        
    return flag

# %%
X = data_set.iloc[:,:-1]
for i in range(len(X.columns)):
    if(detect_outlier(X[X.columns[i]])):
        print(X.columns[i], 'Contains Outlier')
# Out:
# pelvic_incidence Contains Outlier
# pelvic_tilt Contains Outlier
# lumbar_lordosis_angle Contains Outlier
# sacral_slope Contains Outlier
# pelvic_radius Contains Outlier
# degree_spondylolisthesis Contains Outlier
# pelvic_slope Contains Outlier
# Direct_tilt Contains Outlier
# thoracic_slope Contains Outlier
# cervical_tilt Contains Outlier
# sacrum_angle Contains Outlier
# scoliosis_slope Contains Outlier

# %%
x = data_set.drop('class', axis=1)
y = data_set['class']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predict = lin_reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

lin_mse = mean_squared_error(y_test, predict)
lin_rmse = np.sqrt(lin_mse)
lin_rmse
# Out:
# 0.376859214364408

# %%
data_set.to_csv('data/Dataset_spine.csv', header=False, index=False)

# %%
data_Set = pd.read_csv('data/Dataset_spine.csv')
data_Set.head()
# Out:
#    63.0278175  22.55258597  39.60911701  40.47523153  98.67291675  \
# 0   39.056951    10.060991    25.015378    28.995960   114.405425
# 1   68.832021    22.218482    50.092194    46.613539   105.985135
# 2   69.297008    24.652878    44.311238    44.644130   101.868495
# 3   49.712859     9.652075    28.317406    40.060784   108.168725
# 4   40.250200    13.921907    25.124950    26.328293   130.327871
#
#    -0.254399986  0.744503464  12.5661  14.5386  15.30468  -28.658501  43.5123  \
# 0      4.564259     0.415186  12.8874  17.5323  16.78486  -25.530607  16.1102
# 1     -3.530317     0.474889  26.8343  17.4861  16.65897  -29.031888  19.2221
# 2     11.211523     0.369345  23.5603  12.7074  11.42447  -30.470246  18.8329
# 3      7.918501     0.543360  35.4940  15.9546   8.87237  -16.378376  24.9171
# 4      2.230652     0.789993  29.3230  12.0036  10.40462   -1.512209   9.6548
#
#    1
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)

data = np.loadtxt('./data/Dataset_spine.csv', delimiter=',')

X = data[:,0:12]
Y = data[:,12]

model = Sequential()
model.add(Dense(30, input_dim=12, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=100, batch_size=10)
# Out:
# Epoch 1/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6774 - accuracy: 0.3226
# Epoch 2/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.6774 - accuracy: 0.3226
# Epoch 3/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6767 - accuracy: 0.3194
# Epoch 4/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.6112 - accuracy: 0.3613
# Epoch 5/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2514 - accuracy: 0.6903
# Epoch 6/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.2072 - accuracy: 0.7452
# Epoch 7/100
# 31/31 [==============================] - 0s 1ms/step - loss: 0.1723 - accuracy: 0.7710
# Epoch 8/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1370 - accuracy: 0.8290
# Epoch 9/100
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1589 - accuracy: 0.7871
# Epoch 10/100
# ...

# %%
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, epochs=200, batch_size=10)
# Out:
# Epoch 1/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.2190 - accuracy: 0.6774
# Epoch 2/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1958 - accuracy: 0.6774
# Epoch 3/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1784 - accuracy: 0.6774
# Epoch 4/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1680 - accuracy: 0.6774
# Epoch 5/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1550 - accuracy: 0.6774
# Epoch 6/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1472 - accuracy: 0.6774
# Epoch 7/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 0.6774
# Epoch 8/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1331 - accuracy: 0.6774
# Epoch 9/200
# 31/31 [==============================] - 0s 2ms/step - loss: 0.1300 - accuracy: 0.6774
# Epoch 10/200
# ...

# %%
print(model.evaluate(X, Y)[1])
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0543 - accuracy: 0.9419
# 0.9419354796409607
